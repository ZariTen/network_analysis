# %% [markdown]
# # Respostas das questões da atividade 1 que requerem o uso de Notebook

# %%
# Questão 9
# Mr. A is friend with Mrs. B, but she doesn't like him back. 
#She has a reciprocal friendship with both C and D, but only C considers D a friend. 
#D has also sent friend requests to E, F, G, and H but, so far, only G replied. 
#G also has a reciprocal relationship with A. Draw the corresponding directed graph.

import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()

G.add_nodes_from(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])

G.add_edges_from([('A', 'B'), ('B', 'C'), ('B', 'D'), ('C', 'B'), ('C', 'D'), ('D', 'C'), ('D', 'E'), ('D', 'F'), ('D', 'G'), ('D', 'H'), ('G', 'D'), ('G', 'A'), ('A', 'G')])

plt.figure(figsize=(5, 5))
nx.draw_networkx(G, with_labels=True, node_size=200, node_color='lightblue', font_size=20)
plt.show()

# %%
#Questao 10
#Draw the graph from the previous exercise as undirected and weighted, with the weight being 2 if the connection is reciprocal, 1 otherwise.

import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

G.add_nodes_from(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])

# G.add_edges_from([('A', 'B'), ('B', 'C'), ('B', 'D'), ('C', 'B'), ('C', 'D'), ('D', 'C'), ('D', 'E'), ('D', 'F'), ('D', 'G'), ('D', 'H'), ('G', 'D'), ('G', 'A'), ('A', 'G')])
G.add_edges_from([('A', 'B', {'weight': 2}), ('B', 'C', {'weight': 1}), ('B', 'D', {'weight': 1}), ('C', 'B', {'weight': 1}), ('C', 'D', {'weight': 1}), ('D', 'C', {'weight': 1}), ('D', 'E', {'weight': 1}), ('D', 'F', {'weight': 1}), ('D', 'G', {'weight': 1}), ('D', 'H', {'weight': 1}), ('G', 'D', {'weight': 1}), ('G', 'A', {'weight': 2}), ('A', 'G', {'weight': 2})])

plt.figure(figsize=(8, 8))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=200, node_color='lightblue', font_size=20)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos=nx.spring_layout(G), edge_labels=labels)
plt.show()

# %%
#Questao 7
#Draw the undirected and directed versions of the graph G(V, E), where V = {1, 2, 3, 4, 5, 6} and E = {(2, 5), (6, 1), (5, 3), (2, 3)}.

import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

V = [1, 2, 3, 4, 5, 6]
E = [(2, 5), (6, 1), (5, 3), (2, 3)]

G.add_nodes_from(V)
G.add_edges_from(E)

plt.figure(figsize=(4, 4))
nx.draw_networkx(G, with_labels=True, node_size=200, node_color='lightblue', font_size=20)
plt.show()
